# %%
import timescape_functions as tf

base_url = "https://osdf.osg-htc.org/ospool/ap40/data/adrian.fisher/FITS"

tf.save_job_pickle(base_url, "SDSS/full_sdss.csv", "pickle_test", 6, 16)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 import timescape_functions as tf
#       3 base_url = "https://osdf.osg-htc.org/ospool/ap40/data/adrian.fisher/FITS"
# ----> 5 tf.save_job_pickle(base_url, "SDSS/full_sdss.csv", "pickle_test", 6, 16)
#
# File c:\Users\newmr\Documents\GitHub\capstone-project\timescape_functions.py:603, in save_job_pickle(base_url, source_csv_file, out_folder, start, end)
#     601 def save_job_pickle(base_url, source_csv_file, out_folder, start, end):
#     602     file_list = construct_url_list(source_csv_file, base_url, start, end)
# --> 603     result = collect_values(file_list)
#     605     filename = f'pickle_{start}_{end}.pkl'
#     607     out_path = Path(out_folder)
#
# File c:\Users\newmr\Documents\GitHub\capstone-project\timescape_functions.py:525, in collect_values(files)
#     523 # Collect values
# ...
